# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %%
import time
import random
import nltk
from nltk.corpus import words

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to /home/dkc/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
english_words = words.words()
length_5_words= []
length_5_non_repeating_char_words = []
for el in english_words:
    if len(el)==5:
        length_5_words.append(el.upper())
        if len(set(el))==5:

            length_5_non_repeating_char_words.append(el.upper())
            
random.shuffle(length_5_non_repeating_char_words)

# %%
class MyList:
    def __init__(self):
        self.elements =[]

    def insert(self, element):
        self.elements.append(element)

    def search(self, data):
        return data in self.elements

# Students have to write similar classes for MySortedList, MyBST and MyHashMap

# %%
def give_colors(true_word, guess):
    """ takes two strings of length N. 
    returns a list of length N with values 0,1 or 2. 
    No repeating characters in both true word and guess.
    """
    ans = []
    N = len(guess)
    for i in range(N):
        if guess[i] not in true_word:
            ans.append(0)
        elif guess[i] == true_word[i]:
            ans.append(2)
        else:
            ans.append(1)
    return ans

# %%
def is_candidate(guess_list,colors_list, word_to_check):
    for i in range(len(guess_list)):
        colors = give_colors(true_word=word_to_check, guess=guess_list[i])
        if colors != colors_list[i]:
            return False
    return True

# %%
def guess_word_from_prev(guess_list,colors_list,simple_word_list, num_try):
    # Students have to write this function also.

    # guess_list : list of length k,  (integer k, can be zero)
    # each element in this list is a string of length N. 
    #  string only contains upper case A to Z
     
    #  colors_list : list of length k,
    #  each element in this list is a list of length N.
    #  each element in this list is either 0 or 1 or 2.
    #  0 stands for gray, 1 for yellow and 2 for green.

    #  simple_word_list is a list of length V, containing 
    #  a small subset of the set of words in the vocab list.
    #  each element in this list is a string of length N. 
    #  string only contains upper case A to Z.
    #  Can be used for initial few guesses.

    # num_try is a number indicating how many times we have failed in generating a
    # valid vocabulary word with the current guess/color info
    
    # Returns a guess of the possible answer. 
    # This need not be a word in the vocabulary 
    # as you do not have access to the vocabulary here.
    if len(guess_list) == 0:
        return simple_word_list[random.randint(0, len(simple_word_list)-1)]
    elif len(guess_list) <= 5 or num_try > 100:
        new_simple_word_list = []
        for word in simple_word_list:
            if is_candidate(guess_list,colors_list, word):
                new_simple_word_list.append(word)
        if new_simple_word_list:
            return new_simple_word_list[random.randint(0, len(new_simple_word_list)-1)]
        else:
            return simple_word_list[random.randint(0, len(simple_word_list)-1)]
    else:
        # Define the pool of characters
        letters = list(string.ascii_uppercase)
        #remove letters which are 0s in colors_list
        for i in range(len(guess_list)):
            for j in range(len(simple_word_list[0])):
                if colors_list[i][j] == 0 and guess_list[i][j] in letters:
                    letters.remove(guess_list[i][j])
        random_word = ''.join(random.choices(letters, k=len(simple_word_list[0])))
        return random_word

# %%
# Tournament 1
# Students are not expected to write anything here, and is only meant to show how their 
# guess_word_from_prev function, and the insert/search functions in their implementations 
# of MySortedList, MyBST and MyHashMap will be used. 
# Using any variable names here as a hint in the functions to be implemented is 
# illegal and will backfire, as all variable names in this cell can be changed.

legal_word_list = length_5_non_repeating_char_words[:-2000] # all but the last 2000 words
simple_word_list = legal_word_list[:100] # first 100 words as a starter pack that is given.

N = 5 # number of characters in each word
vocabulary = MyList() # It can also be MyBST or MySortedList or MyHashMap
# all of these classes must support an insert function and a search function
for el in legal_word_list:
    vocabulary.insert(el) 
wordle_answers = []
for j in range(20): # 20 puzzles per tournament
    wordle_answers.append(legal_word_list[random.randint(0,len(legal_word_list)-1)])

error_flag = False
for j in range(20):
    correct_solution = wordle_answers[j]
    guess_list = []
    colors_list = []

    while 2>1: # In each cycle of this loop one valid guess is made and a new colors info is acquired.
        num_try = 0 # try number to guess a word in vocabulary that agrees with the results so far
        while 2>1: 
            # Within each cycle of this loop an attmept to find a word in the vocabulary that obeys colors is made.
            # the loop terminates when a valid word in the vocabulary is found
            guess =  guess_word_from_prev(guess_list, colors_list, simple_word_list, num_try)
            num_try += 1
            if vocabulary.search(guess):
                break
            if num_try > 10000:
                error_flag = True
                break
        if error_flag:
            break
        guess_list.append(guess)
        colors = give_colors(correct_solution, guess)
        colors_list.append(colors)
        if sum(colors) == 2*N:
            break
        if len(guess_list)>1000:
            error_flag = True
            break
    print("Tournament 1, puzzle ",j)
    if error_flag:
        print("Tried too many non-dictionary words in a single situation or tried too many guesses.")
    else:
        print("Guesses :", guess_list)
        print("Number of guesses :", len(guess_list))
        print("Solution :", correct_solution)
    print("====================")
# Out:
# Tournament 1, puzzle  0
# Guesses : ['FUMER', 'AOTEA', 'SERON', 'STEIN', 'PUNGA', 'MANIU', 'KRENG', 'JOSIP', 'KRENG', 'SERON', 'BENDY', 'CHIVE', 'SNACK', 'UVITO', 'ETHAN', 'SERON', 'HOURI', 'ELIAN', 'SHEAR', 'DAUBE', 'KADMI', 'APHRA', 'AMITA', 'JOSIP', 'CHAPE', 'CUSIE', 'TOMAN', 'FRAYN', 'MORIC', 'GIVEN', 'BATHE', 'IKONA', 'LIMBO', 'IANUS', 'KRENG', 'TEXAN', 'WRUNG', 'WRUNG', 'ETHAN', 'BENDY', 'GAULT', 'AITCH', 'FERIA', 'SHEAR', 'XICAK', 'SITAR', 'STANE', 'KRENG', 'SHEAR', 'IKONA', 'ANTES']
# Number of guesses : 51
# Solution : ANTES
# ====================
# Tournament 1, puzzle  1
# Guesses : ['LYARD', 'VAULT', 'IKONA', 'APHRA', 'XICAK', 'ROUTE', 'CUSIE', 'BULGE', 'ABRAM', 'CEIBO', 'WRITE', 'JUMBO', 'RATEL', 'MYOID', 'DELFT', 'GIVEN', 'LABIS', 'MOTEL', 'CHIVE', 'RIGOL', 'RHAMN', 'AITCH', 'HOURI', 'BRACE', 'CEIBO', 'HELIX', 'VAULT', 'RETAN', 'SUBAH', 'CULPA', 'BATHE', 'FERIA', 'BLAKE', 'APHRA', 'FRAYN', 'MANIU', 'NEXUM', 'MORIC', 'BRACE', 'PUNGA', 'BULGE', 'RHAMN', 'HILUM', 'UVITO', 'ALTER', 'JUGAL', 'DEWAN', 'FERIA', 'FERIA', 'KADMI', 'MOTEL', 'CURIE', 'KEMPY', 'APHRA', 'CHAPE', 'IKONA', 'ATONY', 'XICAK', 'AITCH', 'MANIU', 'SOUPY', 'ABRAM', 'CULPA', 'CRYPT', 'HELIX', 'ATONY', 'BARGE', 'VAULT', 'XICAK', 'FEUAR', 'THAWN', 'HILUM', 'CRIMP', 'IKONA', 'FUMER', 'NEXUM', 'ENACT', 'SERON', 'NATHE', 'CRIMP', 'GEOTY', 'STEIN', 'FUMER', 'YIELD', 'JUMBO', 'UNIAT', 'BATHE', 'IANUS', 'BARGE', 'BRACE', 'ENACT', 'CUSIE', 'RHAMN', 'SOWER', 'NATHE', 'HELIX', 'CHAPE', 'CURST', 'BARGE', 'BENDY', 'RIGOL', 'DORIA', 'PORED', 'SOUPY', 'FRAYN', 'SERON', 'JUMBO', 'MOTEL', 'FERIA', 'THAWN', 'GEOTY', 'MOTED', 'SOUPY', 'BARGE', 'CRIMP', 'MANIU', 'SIZAL', 'NATHE', 'HILUM', 'COURS', 'FUMER', 'NATHE', 'KRENG', 'BLAKE', 'AITCH', 'AYOND', 'ONIUM', 'DORIA', 'FUMER', 'DEWAN', 'TOMAN', 'MORIC', 'CEIBO', 'LABIS', 'UVITO', 'HOURI', 'ONIUM', 'ROUTE', 'CEIBO', 'SERON', 'APHRA', 'GEOTY', 'BRACE', 'WRUNG', 'APHRA', 'MANIU', 'XICAK', 'WRITE', 'GLOZE', 'MYOID', 'WRUNG', 'CRIMP', 'AOTEA', 'UVITO', 'AITCH', 'BULGE', 'MOTEL', 'ELIAN', 'KADMI', 'AZOTE', 'ALTER', 'SHEAR', 'PUNIC', 'LIMBO', 'YIELD', 'MANIU', 'ONIUM', 'BASIL']
# Number of guesses : 168
# Solution : BASIL
# ====================
# Tournament 1, puzzle  2
# Guesses : ['YIELD', 'ENACT', 'RIGOL', 'SHEAR', 'NEXUM', 'FROTH', 'DEWAN', 'CRIMP', 'SOUPY', 'HYING', 'UNIAT', 'FRAYN', 'APHRA', 'RHAMN', 'SOUPY', 'ENACT', 'ETHAN', 'RHAMN', 'DAUBE', 'HOURI', 'CURST', 'DURYL', 'BRACE', 'LOCHY', 'SNACK', 'BULGE', 'IKONA', 'AITCH', 'SOWER', 'SOUPY', 'GLOZE', 'SNACK', 'VAULT', 'RETAN', 'WRITE', 'AZOTE', 'DEWAN', 'JOSIP', 'AMITA', 'PUNGA', 'RETAN', 'KADMI', 'RHAMN', 'KRENG', 'MANIU', 'DEWAN', 'PUNGA', 'MORIC', 'TAREQ', 'CUSIE', 'KEMPY', 'SITAR', 'IKONA', 'NEXUM', 'CREAT', 'CHAPE', 'CREAT', 'ALTER', 'RATEL', 'TRACE', 'KADMI', 'BAKER', 'BULGE', 'REACT', 'FERIA', 'ABRAM', 'DURYL', 'ENACT', 'CRETA', 'STEIN', 'KRENG', 'MOTEL', 'BARGE', 'HELIX', 'CRETA', 'DELFT', 'REACT', 'MORIC', 'CARTE', 'PAYER', 'RETAN', 'CURST', 'MORIC', 'LOCHY', 'PUNIC', 'TRACE', 'BRACE', 'ROUTE', 'FERIA', 'AYOND', 'RECTA', 'PUNIC', 'CHIVE', 'CRYPT', 'RATEL', 'JOSIP', 'TRACE', 'AZOTE', 'THAWN', 'CRYPT', 'UVITO', 'CRATE']
# Number of guesses : 102
# Solution : CRATE
# ====================
# Tournament 1, puzzle  3
# Guesses : ['GEOTY', 'BAKER', 'IKONA', 'AITCH', 'RATEL', 'JUMBO', 'PAYER', 'SHEAR', 'ATOPY', 'HOURI', 'FEUAR', 'ALTER', 'THAWN', 'ONIUM', 'BENDY', 'STEIN', 'LYARD', 'JOSIP', 'IKONA', 'PUNIC', 'ABRAM', 'BLAKE', 'LOCHY', 'NATHE', 'RETAN', 'MOTED', 'IKONA', 'HOURI', 'SNACK', 'RETAN', 'GEOTY', 'GEOTY', 'FERIA', 'YIELD', 'KADMI', 'HILUM', 'PUNIC', 'TRACE', 'BAKER', 'HOURI', 'HELIX', 'BARGE', 'DORIA', 'CEIBO', 'UVITO', 'SHEAR', 'WRUNG', 'CURST', 'ENACT', 'CURST', 'PUNIC', 'LIMBO', 'PORED', 'ONIUM', 'ALTER', 'AMITA', 'CURST', 'YIELD', 'CURST', 'CRYPT', 'CURIE', 'KEMPY', 'VAULT', 'JUMBO', 'ONIUM', 'JUGAL', 'PUNIC', 'APHRA', 'UVITO', 'LYARD', 'CHAPE', 'SERON', 'DURYL', 'DEWAN', 'DORIA', 'RATEL', 'MOTEL', 'UVITO', 'MOTED', 'RIGOL', 'AYOND', 'PROAL', 'KEMPY', 'CURIE', 'HILUM', 'FERIA', 'RETAN', 'PUNIC', 'HILUM', 'AITCH', 'TOMAN', 'HYING', 'MANIU', 'TOMAN', 'PAYER', 'AMITA', 'PUNGA', 'MOTED', 'ATOPY', 'JOSIP', 'SHEAR', 'HOURI', 'BARGE', 'DORIA', 'FERIA', 'YIELD', 'ROUTE', 'JOSIP', 'CHAPE', 'SITAR', 'SHEAR', 'GLOZE', 'CURIE', 'PROAL', 'HOURI', 'CURIE', 'DORIA', 'PORED', 'SOWER', 'CURST', 'ATOPY', 'DEWAN', 'TOMAN', 'FERIA', 'ATONY', 'RATEL', 'CHIVE', 'CRYPT', 'WRUNG', 'SCYTH']
# Number of guesses : 130
# Solution : SCYTH
# ====================
# Tournament 1, puzzle  4
# Guesses : ['PAYER', 'TOMAN', 'XICAK', 'SUBAH', 'BRACE', 'IKONA', 'BAKER', 'PAYER', 'HYING', 'HYING', 'MOTEL', 'KADMI', 'PORED', 'PORED', 'SOWER', 'HELIX', 'DELFT', 'SHEAR', 'RHAMN', 'ATONY', 'GLOZE', 'GLOZE', 'MYOID', 'BATHE', 'KADMI', 'MOTED', 'CURIE', 'SHEAR', 'SERON', 'BENDY', 'ENACT', 'COURS', 'BARGE', 'HELIX', 'GAULT', 'HILUM', 'AITCH', 'FRAUD', 'LYARD', 'BARGE', 'COURS', 'APHRA', 'PORED', 'AZOTE', 'TOMAN', 'THAWN', 'BARGE', 'LIMBO', 'GUSLA', 'STEIN', 'ATONY', 'IANUS', 'ALTER', 'ENACT', 'AMITA', 'PROAL', 'PAYER', 'GUSLA', 'GEOTY', 'PORED', 'HELIX', 'RATEL', 'BATHE', 'ALTER', 'DAUBE', 'HYING', 'VAULT', 'AITCH', 'LOCHY', 'GAULT', 'ATONY', 'FROTH', 'GUSLA', 'THAWN', 'WRUNG', 'SITAR', 'AMITA', 'AYOND', 'COURS', 'ELIAN', 'XICAK', 'PROAL', 'FROTH', 'AYOND', 'SHEAR', 'FUMER', 'MANIU', 'TRACE', 'SUBAH', 'BENDY', 'RETAN', 'WRUNG', 'MOTED', 'SHEAR', 'AITCH', 'BRACE', 'ELIAN', 'FROTH', 'AOTEA', 'CUSIE', 'WRUNG', 'GUSLA', 'AMITA', 'DORIA', 'BARGE', 'AOTEA', 'RATEL', 'DORIA', 'BULGE', 'NEXUM', 'ALTER', 'ELIAN', 'AITCH', 'CURIE', 'AMITA', 'PAYER', 'BRACE', 'RIGOL', 'MANIU', 'SNACK', 'LOCHY', 'BATHE', 'JUMBO', 'FRAYN', 'STEIN', 'HELIX', 'FULAH']
# Number of guesses : 127
# Solution : FULAH
# ====================
# Tournament 1, puzzle  5
# Guesses : ['ALTER', 'AYOND', 'FRAUD', 'UVITO', 'TOMAN', 'DELFT', 'GIVEN', 'SOUPY', 'FRAUD', 'DORIA', 'ONIUM', 'SITAR', 'WRITE', 'KADMI', 'DORIA', 'PUNGA', 'KEMPY', 'ABRAM', 'PORED', 'UVITO', 'HYING', 'SERON', 'PORED', 'AZOTE', 'PUNGA', 'ABRAM', 'UVITO', 'LIMBO', 'NEXUM', 'LYARD', 'PORED', 'ALTER', 'SOUPY', 'WRUNG', 'ONIUM', 'ROUTE', 'SOWER', 'JOSIP', 'BATHE', 'YIELD', 'WRITE', 'GLOZE', 'RATEL', 'BAKER', 'GLOZE', 'CHIVE', 'KEMPY', 'ENACT', 'STEIN', 'ATONY', 'ATOPY', 'CHIVE', 'ONIUM', 'GUSLA', 'BARGE', 'SOUPY', 'SHEAR', 'COURS', 'SHEAR', 'PUNIC', 'CRYPT', 'ADOXA']
# Number of guesses : 62
# Solution : ADOXA
# ====================
# Tournament 1, puzzle  6
# Guesses : ['JUGAL', 'SOWER', 'PORED', 'TRACE', 'BULGE', 'CUSIE', 'DURYL', 'CRYPT', 'CURST', 'SERON', 'SOWER', 'IANUS', 'ENACT', 'MYOID', 'SOUPY', 'CRYPT', 'IKONA', 'WRITE', 'AMITA', 'GLOZE', 'GEOTY', 'GUSLA', 'JUMBO', 'DEWAN', 'LYARD', 'GUSLA', 'ABRAM', 'NEXUM', 'CRYPT', 'UNIAT', 'GIVEN', 'CRYPT', 'AYOND', 'WRUNG', 'FRAYN', 'DAUBE', 'JOSIP', 'ROUTE', 'IANUS', 'LOCHY', 'JOSIP', 'SITAR', 'ATONY', 'ELIAN', 'ELIAN', 'DEWAN', 'UNIAT', 'MOTEL', 'THAWN', 'GUSLA', 'LIMBO', 'BAKER', 'HILUM', 'BRACE', 'SIGMA', 'ATONY', 'ORSON', 'PROAL', 'LIMBO', 'MORIC', 'DAUBE', 'DELFT', 'BULGE', 'ETHAN', 'ONIUM', 'COURS', 'SERON', 'AMITA', 'KADMI', 'SHORN']
# Number of guesses : 70
# Solution : SHORN
# ====================
# Tournament 1, puzzle  7
# Guesses : ['LIMBO', 'ELIAN', 'BLAKE', 'FRAYN', 'KRENG', 'MANIU', 'FRAYN', 'NATHE', 'FRAUD', 'ONIUM', 'KEMPY', 'SOUPY', 'ATONY', 'AMITA', 'BULGE', 'WRITE', 'RHAMN', 'MANIU', 'JOSIP', 'ETHAN', 'KADMI', 'MOTED', 'MANIU', 'NATHE', 'CURST', 'MYOID', 'FROTH', 'MOTED', 'ALTER', 'ELIAN', 'SNACK', 'DORIA', 'WRUNG', 'ROUTE', 'PAYER', 'THAWN', 'GATER', 'YIELD', 'RHAMN', 'CRYPT', 'FRAUD', 'TRACE', 'ERIAN', 'RIGOL', 'YIELD', 'FUMER', 'SNACK', 'MOTED', 'CRIMP', 'LYARD', 'DAUBE', 'GUSLA', 'DURYL', 'FRAYN', 'BLAKE', 'ELIAN', 'CURIE', 'BRACE', 'ATONY', 'WRUNG', 'JUMBO', 'LIMBO', 'RHAMN', 'ATOPY', 'PUNGA', 'NEXUM', 'ETHAN', 'AMITA', 'MOTED', 'XICAK', 'BAKER', 'MANIU', 'NEXUM', 'SHEAR', 'BRACE', 'BATHE', 'IKONA', 'STEIN', 'HILUM', 'GLOZE', 'JUGAL', 'FEUAR', 'PUNIC', 'ABRAM', 'ROUTE', 'XICAK', 'KEMPY', 'GAULT', 'AMITA', 'UNIAT', 'BATHE', 'BATHE', 'NEXUM', 'SHEAR', 'PUNGA', 'CRYPT', 'NATHE', 'MANIU', 'TOMAN', 'KEMPY', 'CUSIE', 'MANIU', 'CUSIE', 'DEWAN', 'KRENG', 'JOSIP', 'CURIE', 'AITCH', 'MYOID', 'DELFT', 'AMITA', 'VAULT', 'MYOID', 'WRITE', 'BLAKE', 'AMITA', 'AMITA', 'SNACK', 'RATEL', 'ERIAN', 'MYOID', 'FUMER', 'JUGAL', 'CUSIE', 'SHEAR', 'TOMAN', 'MOTEL', 'HYING', 'MOTED', 'ELIAN', 'MYOID', 'ETHAN', 'BLAKE', 'JUGAL', 'CURIE', 'MANIU', 'CRIMP', 'MYOID', 'DORIA', 'DORIA', 'ELIAN', 'CURST', 'TAMIL']
# Number of guesses : 143
# Solution : TAMIL
# ====================
# Tournament 1, puzzle  8
# Guesses : ['HILUM', 'LYARD', 'THAWN', 'ATONY', 'ROUTE', 'BENDY', 'XICAK', 'RHAMN', 'FROTH', 'WRITE', 'GAULT', 'CEIBO', 'TRACE', 'TRACE', 'CRIMP', 'LIMBO', 'BENDY', 'FROTH', 'LIMBO', 'GAULT', 'ENACT', 'ROUTE', 'ONIUM', 'ATOPY', 'PUNIC', 'CRYPT', 'MYOID', 'PAYER', 'GUSLA', 'UVITO', 'DORIA', 'DAUBE', 'CUSIE', 'ENACT', 'GEOTY', 'RIGOL', 'BATHE', 'DURYL', 'ONIUM', 'RATEL', 'XICAK', 'SITAR', 'WRUNG', 'ELIAN', 'DAUBE', 'RHAMN', 'PAYER', 'UNIAT', 'ERIAN', 'PUNGA', 'AMITA', 'NEXUM', 'NATHE', 'MYOID', 'NATHE', 'AZOTE', 'DORIA', 'ONIUM', 'PUNIC', 'PAYER', 'VAULT', 'KADMI', 'APHRA', 'ONIUM', 'JOSIP', 'WRITE', 'CUSIE', 'LOCHY', 'JUMBO', 'ATOPY', 'DEWAN', 'XICAK', 'TRACE', 'JOSIP', 'CRYPT', 'DURYL', 'BLAKE', 'FERIA', 'ONIUM', 'DEWAN', 'FRAUD', 'FUMER', 'FEUAR', 'LIMBO', 'COURS', 'GATER', 'MOTED', 'VAULT', 'CHIVE', 'GLOZE', 'BENDY', 'ONIUM', 'HYING', 'WRUNG', 'FUMER', 'ALTER', 'SIGMA', 'CHIVE', 'RHAMN', 'CRIMP', 'COURS', 'BULGE', 'VAULT', 'SUBAH', 'RETAN', 'SOWER', 'ENACT', 'CRYPT', 'AOTEA', 'SOWER', 'PUNIC', 'JUGAL', 'CRIMP', 'APHRA', 'BARGE', 'RIGOL', 'ONIUM', 'AYOND', 'MANIU', 'SHEAR', 'WRUNG', 'HILUM', 'GIVEN', 'SOUPY', 'FUMER', 'SERON', 'CUSIE', 'MANIU', 'CRYPT', 'STEIN', 'NEXUM', 'NEXUM', 'PAYER', 'NEXUM', 'PUNIC', 'IANUS', 'CEIBO', 'RETAN', 'JUMBO', 'GUSLA', 'BIHAM']
# Number of guesses : 141
# Solution : BIHAM
# ====================
# Tournament 1, puzzle  9
# Guesses : ['KRENG', 'DORIA', 'BATHE', 'UNIAT', 'IANUS', 'CURIE', 'BULGE', 'RIGOL', 'GEOTY', 'AZOTE', 'SOUPY', 'SNACK', 'BRACE', 'FRAUD', 'TOMAN', 'BLAKE', 'STEIN', 'AITCH', 'RETAN', 'BAKER', 'CHAPE', 'BATHE', 'SHEAR', 'FRAYN', 'AZOTE', 'FEUAR', 'CULPA', 'LOCHY', 'FRAUD', 'RIGOL', 'ALTER', 'SNACK', 'GLOZE', 'ENACT', 'PUNIC', 'CURST', 'MOTED', 'HOURI', 'ENACT', 'FEUAR', 'BULGE', 'AYOND', 'SHEAR', 'AOTEA', 'AOTEA', 'ERIAN', 'RIGOL', 'RETAN', 'MANIU', 'JOSIP', 'SITAR', 'GATER', 'RATEL', 'JUGAL', 'GLOZE', 'JOSIP', 'ATONY', 'BAKER', 'RATEL', 'NEXUM', 'HELIX', 'FRAYN', 'ELIAN', 'PUNGA', 'HOURI', 'SITAR', 'ATOPY', 'BATHE', 'DURYL', 'DELFT', 'JUMBO', 'GIVEN', 'PAYER', 'XICAK', 'NEXUM', 'VAULT', 'JOSIP', 'BULGE', 'MOTEL', 'NATHE', 'RATEL', 'GIVEN', 'FRAUD', 'WRITE', 'UNIAT', 'CRIMP', 'ABRAM', 'ERIAN', 'MANIU', 'WRUNG', 'CHAPE', 'DELFT', 'BATHE', 'RIGOL', 'RIGOL', 'GLOZE', 'SHEAR', 'MORIC', 'FRAUD', 'RATCH']
# Number of guesses : 100
# Solution : RATCH
# ====================
# Tournament 1, puzzle  10
# Guesses : ['RATEL', 'IKONA', 'FROTH', 'HILUM', 'WRUNG', 'JUGAL', 'BATHE', 'VAULT', 'SIGMA', 'BAKER', 'GATER', 'GLOZE', 'TRACE', 'LOCHY', 'YIELD', 'TOMAN', 'HYING', 'BARGE', 'FRAYN', 'FRAYN', 'NEXUM', 'MORIC', 'HYING', 'SHEAR', 'DAUBE', 'BENDY', 'SUBAH', 'LIMBO', 'MOTEL', 'PUNIC', 'ONIUM', 'GUSLA', 'STEIN', 'ONIUM', 'SOUPY', 'PUNGA', 'KEMPY', 'GAULT', 'BLAKE', 'SITAR', 'FROTH', 'JUMBO', 'ATONY', 'SOWER', 'MOTEL', 'JUGAL', 'THAWN', 'CAPON', 'HELIX', 'BRACE', 'WRUNG', 'CURIE', 'SITAR', 'PUNIC', 'FERIA', 'JUMBO', 'PROAL', 'SITAR', 'CAPON', 'SOUPY', 'STEIN', 'STEIN', 'DAUBE', 'ELIAN', 'TOMAN', 'DEWAN', 'GIVEN', 'NEXUM', 'MORIC', 'LIMBO', 'ONIUM', 'SUBAH', 'THAWN', 'CRYPT', 'SHEAR', 'BARGE', 'ATONY', 'STEIN', 'PORED', 'ETHAN', 'RETAN', 'AYOND', 'JUMBO', 'ELIAN', 'FRAUD', 'ALTER', 'WRITE', 'AMITA', 'RIGOL', 'MOTEL', 'PONCA']
# Number of guesses : 91
# Solution : PONCA
# ====================
# Tournament 1, puzzle  11
# Guesses : ['UNIAT', 'SUBAH', 'BLAKE', 'XICAK', 'SIGMA', 'SITAR', 'CULPA', 'HOURI', 'KEMPY', 'JOSIP', 'FRAYN', 'SITAR', 'ETHAN', 'TOMAN', 'FEUAR', 'ERIAN', 'CRIMP', 'DEWAN', 'FEUAR', 'UVITO', 'FUMER', 'ELIAN', 'HELIX', 'KADMI', 'CRIMP', 'ABRAM', 'ROUTE', 'BATHE', 'AMITA', 'HYING', 'FROTH', 'PUNIC', 'SQUAW']
# Number of guesses : 33
# Solution : SQUAW
# ====================
# Tournament 1, puzzle  12
# Guesses : ['BULGE', 'LYARD', 'SERON', 'RIGOL', 'BRACE', 'FRAUD', 'DURYL', 'BAKER', 'AYOND', 'BRACE', 'FRAUD', 'DORIA', 'TOMAN', 'JOSIP', 'BARGE', 'PAYER', 'CHAPE', 'BENDY', 'CRIMP', 'AYOND', 'PAYER', 'ATONY', 'CURST', 'SUBAH', 'JUGAL', 'KRENG', 'CURIE', 'BRACE', 'CURST', 'FERIA', 'AMITA', 'WRITE', 'GLOZE', 'HOURI', 'UNIAT', 'SUBAH', 'KRENG', 'XICAK', 'CHIVE', 'DURYL', 'ONIUM', 'NATHE', 'TOMAN', 'GATER', 'HELIX', 'CRIMP', 'PIROL']
# Number of guesses : 47
# Solution : PIROL
# ====================
# Tournament 1, puzzle  13
# Guesses : ['ONIUM', 'BATHE', 'SHEAR', 'BARGE', 'APHRA', 'TOMAN', 'GUSLA', 'STEIN', 'FUMER', 'MYOID', 'YIELD', 'RIGOL', 'RIGOL', 'LYARD', 'GUSLA', 'FROTH', 'FEUAR', 'TWALE', 'DELFT', 'RETAN', 'SUBAH', 'HELIX', 'PROAL', 'GUSLA', 'HOURI', 'APHRA', 'FEUAR', 'SITAR', 'VAULT', 'KRENG', 'BARGE', 'PAYER', 'SIGMA', 'GAULT', 'PUNGA', 'JUMBO', 'XICAK', 'CHIVE', 'LYARD', 'BLAKE', 'PUNIC', 'HILUM', 'IKONA', 'VAULT', 'GAULT', 'DORIA', 'APHRA', 'AITCH', 'GEOTY', 'GATER', 'JOSIP', 'NATHE', 'BLAKE', 'TOMAN', 'BATHE', 'RATEL', 'DELFT', 'HELIX', 'ABRAM', 'FROTH', 'STALE', 'IKONA', 'ATOPY', 'SITAR', 'RHAMN', 'FROTH', 'HILUM', 'GAULT', 'MOTED', 'ABRAM', 'VAULT', 'WRITE', 'JUMBO', 'GATER', 'JUMBO', 'HOURI', 'LOCHY', 'BATHE', 'JUMBO', 'MOTED', 'ERIAN', 'SOUPY', 'JUMBO', 'IANUS', 'CULPA', 'CUSIE', 'MORIC', 'HILUM', 'KADMI', 'JOSIP', 'ELIAN', 'UVITO', 'AZOTE', 'BULGE', 'GUSLA', 'RIGOL', 'ONIUM', 'PROAL', 'HILUM', 'SIGMA', 'WRUNG', 'AYOND', 'PUNIC', 'LYARD', 'SHEAR', 'MYOID', 'YIELD', 'CHAPE', 'GEOTY', 'DORIA', 'HOURI', 'SERON', 'ALTER', 'CEIBO', 'WRITE', 'BATHE', 'HELIX', 'MOTED', 'YIELD', 'ATOPY', 'IKONA', 'RATEL', 'GLOZE', 'CUSIE', 'CULPA', 'SIGMA', 'WRITE', 'DURYL', 'IANUS', 'DORIA', 'SNACK', 'AOTEA', 'JUMBO', 'PUNIC', 'RETAN', 'NATHE', 'GUSLA', 'LOCHY', 'HYING', 'LYARD', 'STEIN', 'GAULT', 'AMITA', 'BARGE', 'KEMPY', 'PUNGA', 'DELFT', 'CURIE', 'THAWN', 'STEIN', 'SOWER', 'HILUM', 'CRYPT', 'KEMPY', 'NEXUM', 'GIVEN', 'PUNGA', 'CURST', 'FRAUD', 'AMITA', 'SOWER', 'WRUNG', 'JUMBO', 'SOUPY', 'TATES', 'TATES', 'NATHE', 'FRAYN', 'YIELD', 'MOTED', 'HYING', 'COURS', 'STEAL']
# Number of guesses : 173
# Solution : STEAL
# ====================
# Tournament 1, puzzle  14
# Guesses : ['CURST', 'AOTEA', 'KRENG', 'ONIUM', 'ROUTE', 'KEMPY', 'COURS', 'COURS', 'NEXUM', 'ETHAN', 'DORIA', 'SOUPY', 'FRAYN', 'GIVEN', 'ENACT', 'IKONA', 'RIGOL', 'BLAKE', 'TUBER']
# Number of guesses : 19
# Solution : TUBER
# ====================
# Tournament 1, puzzle  15
# Guesses : ['BRACE', 'SHEAR', 'LOCHY', 'AOTEA', 'SOUPY', 'DORIA', 'STEIN', 'MYOID', 'YIELD', 'STEIN', 'WRITE', 'IANUS', 'HELIX', 'GEOTY', 'GLOZE', 'PROAL', 'RIGOL', 'DEWAN', 'NEXUM', 'CHAPE', 'MORIC', 'UVITO', 'HYING', 'VAULT', 'GLOZE', 'FROTH', 'SOUPY', 'HYING', 'DELFT', 'ATONY', 'CUSIE', 'BRACE', 'CHAPE', 'BENDY', 'KRENG', 'BENDY', 'GATER', 'ENACT', 'ELIAN', 'UVITO', 'JUGAL', 'RETAN', 'NATHE', 'CHIVE', 'TOMAN', 'ETHAN', 'SERTA', 'APHRA', 'KADMI', 'MORIC', 'RETAN', 'ABRAM', 'RETAN', 'JUGAL', 'CRYPT', 'AOTEA', 'DEWAN', 'HYING', 'TOMAN', 'IANUS', 'HELIX', 'CHIVE', 'ONIUM', 'JUMBO', 'TERAS', 'SUBAH', 'STEIN', 'RETAN', 'CULPA', 'JUMBO', 'UNIAT', 'DORIA', 'BARGE', 'SERTA', 'FRAYN', 'SOUPY', 'SUBAH', 'BRACE', 'SITAR', 'TATES', 'ABRAM', 'HYING', 'RHAMN', 'STRAE', 'WRUNG', 'ROUTE', 'THAWN', 'ENACT', 'KRENG', 'ATOPY', 'GIVEN', 'SNACK', 'FRAUD', 'TRACE', 'STEIN', 'CHIVE', 'ABRAM', 'DELFT', 'KEMPY', 'TATES', 'MOTEL', 'HILUM', 'JUGAL', 'BLAKE', 'UVITO', 'DORIA', 'SERTA', 'DAUBE', 'LIMBO', 'DAUBE', 'KEMPY', 'MANIU', 'RIGOL', 'IANUS', 'GEOTY', 'GATER', 'KADMI', 'NATHE', 'PAYER', 'AMITA', 'WRITE', 'YIELD', 'SUBAH', 'FUMER', 'FRAUD', 'SUBAH', 'UVITO', 'XICAK', 'ETHAN', 'ENACT', 'ELIAN', 'ATONY', 'TATES', 'GAULT', 'JOSIP', 'PAYER', 'MORIC', 'FRAYN', 'ONIUM', 'DELFT', 'ELIAN', 'VAULT', 'THAWN', 'CHAPE', 'TRACE', 'DEWAN', 'TATES', 'TAREQ', 'STRAE', 'KRENG', 'SITAR', 'ABRAM', 'CHIVE', 'PORED', 'BLAKE', 'AYOND', 'FRAUD', 'NEXUM', 'ETHAN', 'AYOND', 'AMITA', 'CURIE', 'CHIVE', 'PUNGA', 'TATES', 'CRYPT', 'SERTA', 'HILUM', 'TATES', 'KRENG', 'ONIUM', 'LOCHY', 'ALTER', 'BAKER', 'RHAMN', 'SERON', 'ETHAN', 'IANUS', 'FRAYN', 'TRACE', 'WRUNG', 'NATHE', 'YIELD', 'COURS', 'SOWER', 'FROTH', 'RETAN', 'ENACT', 'STARE', 'TRACE', 'FUMER', 'ABRAM', 'JOSIP', 'TOMAN', 'ASTER']
# Number of guesses : 195
# Solution : ASTER
# ====================
# Tournament 1, puzzle  16
# Guesses : ['JUGAL', 'HELIX', 'GEOTY', 'CRIMP', 'XICAK', 'DEWAN', 'BLAKE', 'CULPA', 'FUMER', 'AITCH', 'HELIX', 'DURYL', 'SIGMA', 'PUNIC', 'PUNGA', 'DURYL', 'BRACE', 'ELIAN', 'FEUAR', 'SUBAH', 'YIELD', 'SITAR', 'PUNGA', 'IANUS', 'CHIVE', 'FERIA', 'TRACE', 'PUNGA', 'KADMI', 'ATOPY', 'CRYPT', 'SUBAH', 'FRAUD', 'CRIMP', 'FERIA', 'SUBAH', 'AITCH', 'MOTEL', 'PORED', 'LYARD', 'PUNIC', 'HYING', 'DELFT', 'ABRAM', 'CEIBO', 'AITCH', 'RATEL', 'DELFT', 'OLSON', 'VAULT', 'ROUTE', 'UNIAT', 'DURYL', 'MOTEL', 'CURIE', 'ALTER', 'BATHE', 'CHIVE', 'SERON', 'RHAMN', 'GEOTY', 'XICAK', 'ONIUM', 'COURS', 'YIELD', 'AITCH', 'FRAYN', 'BARGE', 'ABRAM', 'ATOPY', 'IANUS', 'DURYL', 'WRUNG', 'PAYER', 'FERIA', 'FUMER', 'ONIUM', 'STEIN', 'TRACE', 'CULPA', 'TOMAN', 'DORIA', 'ENACT', 'CULPA', 'BULGE', 'LYARD', 'RIGOL', 'HOURI', 'CRIMP', 'AYOND', 'RETAN', 'AZOTE', 'AMITA', 'CURIE', 'HELIX', 'FERIA', 'CURST', 'TOMAN', 'COURS', 'MANIU', 'SLONE']
# Number of guesses : 101
# Solution : SLONE
# ====================
# Tournament 1, puzzle  17
# Guesses : ['KEMPY', 'STEIN', 'JUMBO', 'ERIAN', 'CRIMP', 'APHRA', 'CURIE', 'PUNGA', 'MORIC', 'MOTEL', 'ROUTE', 'RATEL', 'MORIC', 'MOTED', 'AMITA', 'FEUAR', 'AOTEA', 'ELIAN', 'HOURI', 'ERIAN', 'AOTEA', 'AYOND', 'GUSLA', 'PAYER', 'BULGE', 'GLOZE', 'CHIVE', 'GAULT', 'PAYER', 'KEMPY', 'FRAYN', 'THAWN', 'MANIU', 'PORED', 'GIVEN', 'CRIMP', 'FUMER', 'FROTH', 'FRAYN', 'SHEAR', 'SUSAN', 'CURST', 'MORIC', 'KEMPY', 'RHAMN', 'BENDY', 'CUSIE', 'SNACK', 'IANUS', 'CHAPE', 'CHIVE', 'ATONY', 'CRYPT', 'DURYL', 'SHEAR', 'ONIUM', 'JUGAL', 'SOUPY', 'TRACE', 'GATER', 'SNACK', 'DURYL', 'USNEA']
# Number of guesses : 63
# Solution : USNEA
# ====================
# Tournament 1, puzzle  18
# Guesses : ['VAULT', 'PORED', 'ENACT', 'ROUTE', 'BAKER', 'RIGOL', 'GAULT', 'RATEL', 'SHEAR', 'ETHAN', 'BRACE', 'PORED', 'ETHAN', 'IANUS', 'ENACT', 'SITAR', 'KADMI', 'CULPA', 'GAULT', 'SERON', 'SOUPY', 'ELIAN', 'FERIA', 'IKONA', 'LYARD', 'WRITE', 'MORIC', 'NEXUM', 'ETHAN', 'UNIAT', 'BARGE', 'PORED', 'UNIAT', 'RHAMN', 'BATHE', 'FRAYN', 'CULPA', 'ATOPY', 'GATER', 'CRIMP', 'CUSIE', 'ETHAN', 'WRITE', 'HILUM', 'WRITE', 'DELFT', 'ETHAN', 'ATONY', 'MORIC', 'CUSIE', 'ALTER', 'ERIAN', 'CRYPT', 'GATER', 'LIMBO', 'BARGE', 'SITAR', 'FUMER', 'CEIBO', 'BRACE', 'HELIX', 'CULPA', 'AOTEA', 'GAULT', 'DAUBE', 'BAKER', 'FROTH', 'YIELD', 'RHAMN', 'AMITA', 'DEWAN', 'TOMAN', 'HELIX', 'RIGOL', 'BAKER', 'AZOTE', 'ATOPY', 'XICAK', 'GUSLA', 'PUNIC', 'KRENG', 'CURST', 'BLAKE', 'GIVEN', 'ONIUM', 'HOURI', 'GAULT', 'FUMER', 'WRITE', 'STEIN', 'MYOID', 'BATHE', 'ALTER', 'BATHE', 'MYOID', 'PUNGA', 'FRAUD', 'SOUPY', 'MOTED', 'STEIN', 'BENDY', 'DELFT', 'RIGOL', 'CUSIE', 'JUMBO', 'FRAUD', 'UVITO', 'KADMI', 'BULGE', 'NATHE', 'HELIX', 'AMITA', 'IKONA', 'FROTH', 'CURIE', 'UNIAT', 'MOTED', 'GREBO']
# Number of guesses : 118
# Solution : GREBO
# ====================
# Tournament 1, puzzle  19
# Guesses : ['RHAMN', 'SOUPY', 'YIELD']
# Number of guesses : 3
# Solution : YIELD
# ====================
